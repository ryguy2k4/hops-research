# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/output/separations.csv')
df
# Out:
#           pair  tertiary  separation class
# 0    HH270VLA1     False        99.4    C0
# 1      HOPS-12      True      1853.5    C0
# 2      HOPS-12     False        80.6    C0
# 3     HOPS-168     False        73.7    C0
# 4     HOPS-173     False       103.0    C0
# 5     HOPS-182     False       381.5    C0
# 6     HOPS-193     False       100.0    C1
# 7     HOPS-203     False        49.7    C0
# 8     HOPS-203      True      1085.5    C0
# 9     HOPS-213     False       114.4    FS
# 10    HOPS-281     False       311.6    FS
# 11    HOPS-282     False        70.1    C1
# 12    HOPS-288      True       221.9    C0
# 13    HOPS-288     False        61.3    C0
# 14    HOPS-290     False       332.7    C0
# 15    HOPS-304     False       272.7    FS
# 16    HOPS-312     False       134.7    C0
# 17     HOPS-32     False       162.2    C0
# 18    HOPS-323     False       273.6    C1
# 19  HOPS-361-N     False        37.6    C0
# 20    HOPS-363     False        79.5    FS
# ...

# %%
df[df['tertiary'] == False].describe()
# Out:
#        separation
# count   36.000000
# mean   154.886111
# std    136.258677
# min     24.100000
# 25%     68.950000
# 50%     99.600000
# 75%    195.850000
# max    572.500000

# %% [markdown]
# Among the 36 fields with measured outflow PAs, the maximum binary separation is 572.5 AU, the minimum is 24.1 AU, and the median is 99.6 AU.
