# %%
import warnings
warnings.filterwarnings("ignore")

import astropy.io.fits as fits
import astropy.units as u
from astropy.coordinates import SkyCoord
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import numpy as np
import os
import pandas as pd
import glob

from create_figs import create_m0_map, mark_sources_2, plot_vector, mark_sources

# %%
# script options
overwrite = False
output_folder = "../results/figs_for_poster"

# read data
df = pd.read_csv('../data/output/outflow_data.csv')
source_info = pd.read_csv("../data/output/source_info.csv")
source_info['Main'] = source_info['Main'].apply(lambda x: str(x).casefold())
source_info.set_index('Main', inplace=True)

# helper function to extract channel indices from the data table
def getIdx(listOf):
    ranges = []
    
    for string in listOf:
        if pd.isna(string):  # Skip NaN values
            continue
        
        for part in string.split(', '):
            if '-' in part:  # Handle ranges
                start, end = map(int, part.split('-'))
                ranges.append(np.r_[start:end + 1])  # Use np.r_
            else:  # Handle single values
                ranges.append(int(part))  # Append as integer
    
    # Ensure `ranges` is not empty before passing to np.r_
    if not ranges:
        return np.r_[:]  # Returns an empty np.r_

    return np.r_[tuple(ranges)]  # Use `tuple(ranges)` to avoid errors


figure = plt.figure(figsize=(48, 11))

# This loops through each source field with an angle measurement and creates
# a figure with the separation vector and outflow vector overlayed
for i, field in df.groupby('field').agg('first').reset_index().iterrows():

    # verify output path exists and
    # skip already existing files if you don't want to overwrite them
    target_name = field['field']

    # skip for now, missing data
    if target_name == 'Per-emb-5':
        continue

    # verify output path exists and
    if not os.path.exists(output_folder):
        os.mkdir(output_folder)

    # open image
    image_filename = (glob.glob(f'/Volumes/Alpha/Research/data/{target_name.casefold()}/*12co*.fits') + glob.glob(f'/Volumes/Alpha/Research/data/{target_name.casefold()}/*spw39*.fits'))[0]
    hdulist = fits.open(image_filename)    
    hdu = hdulist[0]

    # set center and size of cutout
    center = SkyCoord(hdu.header['OBSRA'], hdu.header['OBSDEC'], unit=u.degree)
    size = np.array([39, 39]) * u.arcsecond
    distance = field['distance']

    # create figure
    channels = getIdx([field['red_channels'], field['blue_channels']])
    fig = create_m0_map(hdu, center, size, channels, 3, distance, figure, subplot=(3, 12, i+1), multiimage=True)
    fig.set_title(f"{target_name}")

    ### VECTORS
    # plot binary separation angle
    center_origin = np.array([np.mean([field['source_a_ra'], field['source_b_ra']]), np.mean([field['source_a_dec'], field['source_b_dec']])])
    separation_angle_north = field['binary_PA']
    # draw separation vector in both directions
    plot_vector(fig, center_origin, separation_angle_north, color='white', length=0.005)
    plot_vector(fig, center_origin, separation_angle_north + 180, color='white', length=0.005)
    
    # plot each outflow vector
    for j, source in df[df['field'] == target_name].reset_index(drop=True).iterrows():
        # define vector origin at the outflow source
        if source['outflow_source'] == 'both':
            outflow_origin = center_origin
        elif source['outflow_source'] == source['source_a']:
            outflow_origin = np.array([source['source_a_ra'], source['source_a_dec']])
        else:
            outflow_origin = np.array([source['source_b_ra'], source['source_b_dec']])

        # plot outflow vector
        outflow_angle_north = source['outflow_PA']
        plot_vector(fig, outflow_origin, outflow_angle_north, color='red', length=0.005)
        
        # calculate delta_PA
        angle = np.abs(outflow_angle_north - separation_angle_north) % 180
        angle = np.min([angle, 180 - angle])
            
        # display angle between outflow and separation in top left corner
        # source_label = source['outflow_source']
        # if source_label == 'both':
        #     source_label = source['source_a']+'+'+source['source_b']
        # fig.ax.text(25,fig.ax.get_xlim()[1]-55-50*(j), f"{source_label} : {np.abs(angle):.2f}°", fontdict={'fontsize': 6})

    # only show colorbar label on leftmost plots
    if i % 12 != 11:
        fig.colorbar.set_axis_label_text("")

    fig.axis_labels.hide()
    fig.tick_labels.hide()

    ### MARKERS
    # add a marker at each source with legend
    target_info = source_info.loc[target_name.casefold()]
    mark_sources(fig, target_info)

    # add beam label
    # bmaj = hdu.header.get('BMAJ', None)  # Beam major axis in degrees
    # bmin = hdu.header.get('BMIN', None)  # Beam minor axis in degrees
    # fig.ax.text(65, 45, f"{bmaj * 3600:.2f}\" × {bmin * 3600:.2f}\"", fontdict={'fontsize': 3})


plt.subplots_adjust(wspace=0.25, hspace=0.2)
# 5x8
# plt.subplots_adjust(wspace=0.2, hspace=0.2)

# save image
figure.savefig(os.path.join(output_folder, "master_3x12.pdf"))
figure.savefig(os.path.join(output_folder, "master_3x12.png"), dpi=800, transparent=True, bbox_inches='tight')
figure.show()
# Out:
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  3.005e-01 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  1.812e-01 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  2.172e-01 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  9.344e-03 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  2.145e-01 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  2.006e-02 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  5.532e-02 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  2.140e-02 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  1.182e-01 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  1.562e-02 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  1.666e-01 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  1.173e-01 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  1.267e-01 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  6.899e-02 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  4.345e-02 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  3.070e-01 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  3.443e-01 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  7.278e-02 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  6.812e-02 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  2.174e-01 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  3.156e-01 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  5.525e-02 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  2.432e-01 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  6.558e-02 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  7.835e-02 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  2.216e-01 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  8.127e-01 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  2.734e-01 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  1.979e-01 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  1.891e-01 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  4.593e-01 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  3.717e-01 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  6.366e-01 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  1.414e-01 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  1.693e-01 [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  3.700e-01 [aplpy.core]

# %%
fig.beam._beam.__dict__
# Out:
# {'_stale': False,
#  'stale_callback': <function matplotlib.artist._stale_axes_callback(self, val)>,
#  '_axes': <WCSAxesSubplot: title={'center': 'Per-emb-44'}>,
#  '_parent_figure': <Figure size 4800x1100 with 72 Axes>,
#  '_transform': <matplotlib.transforms.CompositeGenericTransform at 0x17fbeee10>,
#  '_transformSet': True,
#  '_visible': True,
#  '_animated': False,
#  '_alpha': None,
#  'clipbox': None,
#  '_clippath': <matplotlib.transforms.TransformedPatchPath at 0x3020f9e50>,
#  '_clipon': False,
#  '_label': '',
#  '_picker': None,
#  '_rasterized': False,
#  '_agg_filter': None,
#  '_mouseover': False,
#  '_callbacks': <matplotlib.cbook.CallbackRegistry at 0x1693ebe90>,
#  '_remove_method': <function list.remove(value, /)>,
#  '_url': None,
#  '_gid': None,
#  '_snap': None,
#  '_sketch': None,
#  '_path_effects': [],
#  '_sticky_edges': _XYPair(x=[], y=[]),
#  '_in_layout': True,
#  '_children': [],
#  '_offset': (0, 0),
#  '_bbox_to_anchor': None,
#  '_bbox_to_anchor_transform': None,
#  '_child': <matplotlib.offsetbox.AuxTransformBox at 0x12f90e1e0>,
#  'loc': 3,
#  'borderpad': 0.4,
#  'pad': 0.5,
#  'prop': <matplotlib.font_manager.FontProperties at 0x15b59c290>,
#  'patch': <matplotlib.patches.FancyBboxPatch at 0x15b564800>}
